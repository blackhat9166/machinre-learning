# %% [markdown]
# #PANDAS

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# to read file and store in variable

# %%
data = pd.read_csv("matches.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.tail(1)  # this head and taill is used to preview first row and last row resp. by default it shows 5 rows if argument is not passed
data.head(3)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
data.shape  # this is udes to know the no. of rows and column
# Out:
# (636, 18)

# %%
data.info()  # here in panda str is consider to be object datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %% [markdown]
# to fetch particular column

# %%
print(data["winner"])  # this is single  column now is a series datatype
print("#############")
print(type(data["winner"] ))
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object
# #############
# <class 'pandas.core.series.Series'>

# %%
data[["team1","team2","winner"]]  # to extract the multiple column
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %% [markdown]
# ILOC

# %%
data.iloc[:,[4,5,10,11]]  # iloc is flexible enough that you can extract anything from the dataframe
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner  win_by_runs
# 0            Sunrisers Hyderabad           35
# 1         Rising Pune Supergiant            0
# 2          Kolkata Knight Riders            0
# ...

# %% [markdown]
# FELTERING ON CONDITION (MASKING USING BOOLEAN SERIES)

# %%
mask = data['win_by_wickets'] > 3
mask
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 631     True
# 632     True
# 633    False
# 634     True
# 635    False
# Name: win_by_wickets, Length: 636, dtype: bool

# %%
data[mask]
# Out:
#       id  season           city        date                   team1  \
# 1      2    2017           Pune  2017-04-06          Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07           Gujarat Lions
# 3      4    2017         Indore  2017-04-08  Rising Pune Supergiant
# 5      6    2017      Hyderabad  2017-04-09           Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09   Kolkata Knight Riders
# ..   ...     ...            ...         ...                     ...
# 628  629    2016  Visakhapatnam  2016-05-21         Kings XI Punjab
# 629  630    2016         Kanpur  2016-05-21          Mumbai Indians
# 631  632    2016         Raipur  2016-05-22        Delhi Daredevils
# 632  633    2016      Bangalore  2016-05-24           Gujarat Lions
# 634  635    2016          Delhi  2016-05-27           Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
mask1 = ((data['city'] == 'Rajkot')  & (data['toss_decision'] == 'bat'))
data[mask1]
# Out:
#       id  season    city        date                        team1  \
# 33    34    2017  Rajkot  2017-04-29                Gujarat Lions
# 581  582    2016  Rajkot  2016-04-14      Rising Pune Supergiants
# 594  595    2016  Rajkot  2016-04-24  Royal Challengers Bangalore
#
#               team2                  toss_winner toss_decision  result  \
# 33   Mumbai Indians                Gujarat Lions           bat     tie
# 581   Gujarat Lions      Rising Pune Supergiants           bat  normal
# 594   Gujarat Lions  Royal Challengers Bangalore           bat  normal
#
#      dl_applied          winner  win_by_runs  win_by_wickets player_of_match  \
# 33            0  Mumbai Indians            0               0       KH Pandya
# 581           0   Gujarat Lions            0               7        AJ Finch
# 594           0   Gujarat Lions            0               6         V Kohli
#
#                                       venue       umpire1       umpire2  \
# ...

# %%
data[mask & mask1]
# Out:
#       id  season    city        date                        team1  \
# 581  582    2016  Rajkot  2016-04-14      Rising Pune Supergiants
# 594  595    2016  Rajkot  2016-04-24  Royal Challengers Bangalore
#
#              team2                  toss_winner toss_decision  result  \
# 581  Gujarat Lions      Rising Pune Supergiants           bat  normal
# 594  Gujarat Lions  Royal Challengers Bangalore           bat  normal
#
#      dl_applied         winner  win_by_runs  win_by_wickets player_of_match  \
# 581           0  Gujarat Lions            0               7        AJ Finch
# 594           0  Gujarat Lions            0               6         V Kohli
#
#                                       venue      umpire1       umpire2  \
# 581  Saurashtra Cricket Association Stadium  VA Kulkarni     CK Nandan
# 594  Saurashtra Cricket Association Stadium   K Bharatan  BNJ Oxenford
#
#      umpire3
# 581      NaN
# 594      NaN

# %% [markdown]
# VALUE COUNT FUNCTION

# %%
data['winner'].value_counts()   # generally used to count the frequency for the catagorical data
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %% [markdown]
# PLOT FUNCTIONS

# %%
data['winner'].value_counts().head().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# series operation

# %%
data.value_counts('team1') + data.value_counts('team2')
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# dtype: int64

# %% [markdown]
# SORT VALUES

# %%
(data.value_counts('team1') + data.value_counts('team2')).sort_values(ascending=False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %%
data.sort_values('city',ascending=True).head()
# Out:
#       id  season       city        date                        team1  \
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
#
#                      team2            toss_winner toss_decision  result  \
# 460       Rajasthan Royals       Rajasthan Royals         field  normal
# 471  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 470       Rajasthan Royals       Rajasthan Royals         field  normal
# 464       Delhi Daredevils    Chennai Super Kings           bat  normal
# 459        Kings XI Punjab    Chennai Super Kings           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
data.sort_values(['city','win_by_runs'],ascending=[False,True]).head()
# Out:
#       id  season           city        date                team1  \
# 315  316    2012  Visakhapatnam  2012-04-09      Deccan Chargers
# 528  529    2015  Visakhapatnam  2015-04-16  Sunrisers Hyderabad
# 618  619    2016  Visakhapatnam  2016-05-13       Mumbai Indians
# 628  629    2016  Visakhapatnam  2016-05-21      Kings XI Punjab
# 530  531    2015  Visakhapatnam  2015-04-18     Delhi Daredevils
#
#                        team2       toss_winner toss_decision  result  \
# 315           Mumbai Indians   Deccan Chargers           bat  normal
# 528         Rajasthan Royals  Rajasthan Royals         field  normal
# 618          Kings XI Punjab    Mumbai Indians           bat  normal
# 628  Rising Pune Supergiants   Kings XI Punjab           bat  normal
# 530      Sunrisers Hyderabad  Delhi Daredevils           bat  normal
#
#      dl_applied                   winner  win_by_runs  win_by_wickets  \
# 315           0           Mumbai Indians            0               5
# ...

# %%
data.drop_duplicates(subset=['city'])
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017            Pune  2017-04-06               Mumbai Indians
# 2      3    2017          Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017          Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 10    11    2017         Kolkata  2017-04-13              Kings XI Punjab
# 14    15    2017           Delhi  2017-04-15             Delhi Daredevils
# 31    32    2017      Chandigarh  2017-04-28          Sunrisers Hyderabad
# 48    49    2017          Kanpur  2017-05-10                Gujarat Lions
# 64    65    2008          Jaipur  2008-04-21              Kings XI Punjab
# 66    67    2008         Chennai  2008-04-23          Chennai Super Kings
# ...

# %% [markdown]
# drop down fuction is used to remove duplicates according to first and last

# %%
data.drop_duplicates(subset=['city','season'])
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 583  584    2016      Hyderabad  2016-04-16          Sunrisers Hyderabad
# 591  592    2016           Pune  2016-04-22  Royal Challengers Bangalore
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 626  627    2016         Kanpur  2016-05-19        Kolkata Knight Riders
# 627  628    2016         Raipur  2016-05-20          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.drop_duplicates(subset='season',keep='last')[['season','winner']].sort_values('season')
#application of above code to have winner in ipl each year from the data
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians

# %% [markdown]
# groupby

# %%
grp = data.groupby('city')
grp

# %%
len(grp)  #there are 30 different cities
# Out:
# 30

# %%
grp.size().sort_values(ascending=False)
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Cuttack            7
# Ranchi             7
# Port Elizabeth     7
# Abu Dhabi          7
# Raipur             6
# Sharjah            6
# Indore             5
# Kochi              5
# Kanpur             4
# Nagpur             3
# Kimberley          3
# East London        3
# Bloemfontein       2
# dtype: int64

# %%
grp.first()  # AS we do last and first
# Out:
#                  id  season        date                        team1  \
# city
# Abu Dhabi       458    2014  2014-04-16        Kolkata Knight Riders
# Ahmedabad       180    2010  2010-03-15             Rajasthan Royals
# Bangalore         5    2017  2017-04-08  Royal Challengers Bangalore
# Bloemfontein    161    2009  2009-05-15             Delhi Daredevils
# Cape Town       118    2009  2009-04-18               Mumbai Indians
# Centurion       133    2009  2009-04-28             Delhi Daredevils
# Chandigarh       32    2017  2017-04-28          Sunrisers Hyderabad
# Chennai          67    2008  2008-04-23          Chennai Super Kings
# Cuttack         186    2010  2010-03-19              Deccan Chargers
# Delhi            15    2017  2017-04-15             Delhi Daredevils
# Dharamsala      225    2010  2010-04-16              Kings XI Punjab
# Durban          123    2009  2009-04-21              Kings XI Punjab
# ...

# %%
print(grp.groups)
data.iloc[457,:]
# Out:
# {'Abu Dhabi': [457, 459, 460, 464, 470, 471, 475], 'Ahmedabad': [179, 186, 194, 197, 481, 486, 497, 500, 525, 532, 535, 539], 'Bangalore': [4, 11, 16, 29, 41, 44, 56, 57, 59, 69, 73, 83, 89, 103, 110, 180, 183, 191, 196, 213, 216, 225, 241, 267, 279, 282, 290, 301, 311, 316, 325, 328, 349, 355, 366, 378, 382, 391, 400, 406, 410, 428, 431, 451, 480, 487, 491, 494, 509, 516, 524, 533, 537, 545, 549, 556, 570, 579, 586, 605, 610, 616, 619, 625, 632, 635], 'Bloemfontein': [160, 164], 'Cape Town': [117, 118, 119, 120, 123, 125, 129], 'Centurion': [132, 135, 136, 146, 147, 148, 155, 156, 165, 169, 170, 171], 'Chandigarh': [31, 34, 45, 47, 60, 68, 72, 80, 93, 96, 107, 176, 192, 195, 204, 214, 242, 255, 283, 286, 320, 329, 332, 339, 353, 365, 390, 399, 408, 435, 439, 447, 504, 508, 511, 543, 551, 565, 568, 578, 585, 588, 596, 611, 614, 621], 'Chennai': [66, 70, 78, 84, 90, 106, 109, 178, 189, 201, 205, 210, 221, 223, 234, 247, 261, 271, 275, 288, 296, 305, 306, 307, 319, 331, 333, 342, 346, 
# ...

# %%
grp.get_group('Sharjah')
# Out:
#       id  season     city        date                  team1  \
# 458  459    2014  Sharjah  2014-04-17       Delhi Daredevils
# 463  464    2014  Sharjah  2014-04-20       Rajasthan Royals
# 465  466    2014  Sharjah  2014-04-22        Kings XI Punjab
# 467  468    2014  Sharjah  2014-04-24  Kolkata Knight Riders
# 472  473    2014  Sharjah  2014-04-27         Mumbai Indians
# 473  474    2014  Sharjah  2014-04-27    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 458  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 463              Kings XI Punjab              Kings XI Punjab         field
# 465          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 467  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 472             Delhi Daredevils               Mumbai Indians           bat
# 473          Chennai Super Kings          Sunrisers Hyderabad           bat
#
# ...

# %%
print(grp.sum().head(3))
print('*****')
print(grp.mean().head(3))
print(grp['id'].mean().head())
# Out:
#               id  season  dl_applied  win_by_runs  win_by_wickets  umpire3
# city
# Abu Dhabi   3263   14098           0          157              16      0.0
# Ahmedabad   4863   24156           0          180              38      0.0
# Bangalore  22299  132861           3         1263             232      0.0
# *****
#                    id       season  dl_applied  win_by_runs  win_by_wickets  \
# city
# Abu Dhabi  466.142857  2014.000000    0.000000    22.428571        2.285714
# Ahmedabad  405.250000  2013.000000    0.000000    15.000000        3.166667
# Bangalore  337.863636  2013.045455    0.045455    19.136364        3.515152
#
#            umpire3
# city
# Abu Dhabi      NaN
# Ahmedabad      NaN
# Bangalore      NaN
# city
# Abu Dhabi       466.142857
# Ahmedabad       405.250000
# Bangalore       337.863636
# Bloemfontein    163.000000
# Cape Town       122.571429
# Name: id, dtype: float64
