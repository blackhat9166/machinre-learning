# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('car.csv')
data.head()
data['Fuel_Type'].value_counts().plot(kind= 'barh')  #catagorical data
# Out:
# <AxesSubplot:>

# %%
#that bar and pie chart is for the catagorical data which have less catogories
#what for the numerical data
data["Kerb_Weight"]
sns.boxplot('Cylinders',data=data)
#if you have a ctagorical data and a numerical data then  you go with box plot
# Out:
# c:\Users\HARSHIT\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Cylinders'>

# %%
pd.crosstab(data['Make'],data['Cylinders']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Make'>
