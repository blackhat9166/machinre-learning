# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
flw = pd.read_csv('Iris.csv')
flw.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
flw.rename(columns={'SepalLengthCm':'sl','SepalWidthCm':'sw','PetalLengthCm':'pl','PetalWidthCm':'pw'},inplace=True)
flw
# Out:
#       Id   sl   sw   pl   pw         Species
# 0      1  5.1  3.5  1.4  0.2     Iris-setosa
# 1      2  4.9  3.0  1.4  0.2     Iris-setosa
# 2      3  4.7  3.2  1.3  0.2     Iris-setosa
# 3      4  4.6  3.1  1.5  0.2     Iris-setosa
# 4      5  5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...  ...             ...
# 145  146  6.7  3.0  5.2  2.3  Iris-virginica
# 146  147  6.3  2.5  5.0  1.9  Iris-virginica
# 147  148  6.5  3.0  5.2  2.0  Iris-virginica
# 148  149  6.2  3.4  5.4  2.3  Iris-virginica
# 149  150  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
setosa = flw[flw['Species'] == 'Iris-setosa']
versicolor= flw[flw['Species'] == 'Iris-versicolor']
virginica = flw[flw['Species'] == 'Iris-virginica']

# %% [markdown]
# Central tendency
# 1. mean
# 2. median
# 3. mode

# %% [markdown]
# 1. in mean we have to take care of the outliers
# 2.  in median we have to take care that the outlueir are not more than half of the dataset
# 3. mode -----  obvious

# %% [markdown]
# Measure of spread

# %% [markdown]
# 1. range
# 2. Interquartile Range (IQR)
# 3. Variance
# 4. Standard deviation

# %%
# range is the differnce between the max and the min
range = np.max(setosa['pl'])-np.min(setosa['pl'])
range
# Out:
# 0.8999999999999999

# %%
# percentiles
np.percentile(versicolor['pl'],90)  #means 90 percent of pl is less than 4.8
# Out:
# 4.8

# %%
#  iqr is lie between more than 25 percentile but less than 75 percentile
iqr = np.percentile(versicolor['pl'],75) - np.percentile(versicolor['pl'],25)
iqr
# Out:
# 0.5999999999999996

# %%
#variance is have squaring so the data is not remain in the original form
print(np.var(setosa['pl']))
print(np.std(setosa['pl'])) 
#is having mod function instead of squaring
# Out:
# 0.029504000000000002
# 0.17176728442867112

# %%
sns.boxplot(setosa['pl'])
#the blue area is iqr
# Out:
# c:\Users\HARSHIT\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pl'>

# %%
# we can also plot 3 of them
sns.boxplot(x =flw['Species'],y =flw['pl'])
# Out:
# <AxesSubplot:xlabel='Species', ylabel='pl'>

# %% [markdown]
# multiclass analysis
# 1. probability density

# %%
#here we cant use histogram only 
sns.distplot(setosa['pl'])
# Out:
# c:\Users\HARSHIT\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='pl', ylabel='Density'>

# %%
sns.FacetGrid(flw,hue='Species',height=6).map(sns.distplot,'pl').add_legend()
# Out:
# c:\Users\HARSHIT\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\HARSHIT\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(flw,hue='Species',height=6).map(sns.distplot,'pw').add_legend()
# Out:
# c:\Users\HARSHIT\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\HARSHIT\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(flw,hue='Species',height=6).map(sns.distplot,'sl').add_legend()
# Out:
# c:\Users\HARSHIT\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\HARSHIT\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(flw,hue='Species',height=6).map(sns.distplot,'sw').add_legend()
# Out:
# c:\Users\HARSHIT\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\HARSHIT\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# 1. PDF  (probability distribution function)
# 2. CDF  (Cumulative Distribution Function)

# %%
#pdf is probability of a particular value in the dataset
#cdf is the probability of all value which is less than the given value
freq ,sp = np.histogram(setosa['pl'],bins=10)
print(freq)
print(sp)
# Out:
# [ 1  1  2  7 12 14  7  4  0  2]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
pdf = freq/np.sum(freq) # this is pdf of each

# %%
cdf = np.cumsum(pdf)  #this our cdf
cdf
# Out:
# array([0.02, 0.04, 0.08, 0.22, 0.46, 0.74, 0.88, 0.96, 0.96, 1.  ])

# %%
plt.plot(sp[1:],pdf)
plt.plot(sp[1:],cdf)

# %%
#now lets have the cdf and  pdf of  all three pl
freq ,sp = np.histogram(setosa['pl'],bins=10)
pdf = freq/np.sum(freq)
cdf = np.cumsum(pdf)  
plt.plot(sp[1:],pdf)
plt.plot(sp[1:],cdf)

freq ,sp = np.histogram(versicolor['pl'],bins=10)
pdf = freq/np.sum(freq)
cdf = np.cumsum(pdf)  
plt.plot(sp[1:],pdf)
plt.plot(sp[1:],cdf)

freq ,sp = np.histogram(virginica['pl'],bins=10)
pdf = freq/np.sum(freq)
cdf = np.cumsum(pdf)  
plt.plot(sp[1:],pdf)
plt.plot(sp[1:],cdf)
