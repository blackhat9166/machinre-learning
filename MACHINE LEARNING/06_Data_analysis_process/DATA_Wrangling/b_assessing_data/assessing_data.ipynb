# %%
#data wrangling
#data gathering --- api, csv,web scraping, databases
#assessing data-----todays topic
#cleaning data

# %% [markdown]
# assessing data is understending the data deeply before apply method to clean data
# - so studying about unclean data and identifying lies in this accessing data catagory

# %% [markdown]
# Types of Unclean Data
# 1. Dirty data-- also known as low quality data. means has content issue
#
# 2. messy data-- also known as untidy data. means which has structural issue

# %% [markdown]
# Dirty Data
# - Duplicate data
# - Missing data
# - Corrupt Data
# - Inaccurate Data

# %% [markdown]
# Messy data
# - which have right information but unevenly divides in column and rows and you find difficulty to draw colclusions if you directly use it
#
# * rules
# 1. each variable forms a column
# 2. each observation forms a row
# 3. each observation unit forms a table

# %% [markdown]
# Types of assessment
# - Manual - looking through the data manually in google sheet
# - Programmatic - by using pandas fuction such as info() describe()
#
#
# Steps in Assessment
#
# 1. Discover
# 2. Document

# %%
import pandas as pd

# %%
patients = pd.read_csv('insulin_patient.csv')
treatment = pd.read_csv('treatment.csv')
adverse = pd.read_csv('adverse_eff.csv')

# %%
print(patients.shape)
print(treatment.shape)
print(adverse.shape)
# Out:
# (503, 14)
# (280, 7)
# (34, 3)

# %% [markdown]
# Quality issue
#
# [completeness, validity, accuracy, consistency] is [cmp, v, a, con] all following quality errors lies in these catagories only
#
# 1. patients
#   - zip code column is stored in decimal format and some are of 4 digit [v]
#   - state coloumn some time full name and some time short form [con]
#   - missing values for contact details 12[cmp]
#   - incorrect data type for sex and dob[?]
#   - hight and wieght are sometimes very unnatural[a]
#   - inconcistence way of storing phone no.[con]
#   - dubplicate data and not usefull data[con]
#
# 2. Treatment
#   - missing value in hba1c_change[cmp]
#   - novodra and orilin column has u attached numbers[v]
#   - only 280 rows are there instead of 350[cmp]
#   - name and sr. name is in lowercase[con]
#   - hba1c_change 9 instead 4 [a]
#   - use of dashes instead of nan innovodra and insulin [con]
#
#
# 3. Adverse reaction

# %%
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          491 non-null    object
#  6   state         491 non-null    object
#  7   zip_code      491 non-null    float64
#  8   country       491 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 55.1+ KB

# %%
treatment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    280 non-null    object
#  1   surname       280 non-null    object
#  2   auralin       280 non-null    object
#  3   novodra       280 non-null    object
#  4   hba1c_start   280 non-null    float64
#  5   hba1c_end     280 non-null    float64
#  6   hba1c_change  171 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB

# %%
adverse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   given_name        34 non-null     object
#  1   surname           34 non-null     object
#  2   adverse_reaction  34 non-null     object
# dtypes: object(3)
# memory usage: 944.0+ bytes

# %%
patients.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  503.000000    491.000000  503.000000  503.000000  503.000000
# mean   252.000000  49084.118126  173.434990   66.634195   27.483897
# std    145.347859  30265.807442   33.916741    4.411297    5.276438
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    126.500000  21920.500000  149.300000   63.000000   23.300000
# 50%    252.000000  48057.000000  175.300000   67.000000   27.200000
# 75%    377.500000  75679.000000  199.500000   70.000000   31.750000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %%
treatment.describe()
# 50 to 75 is going very sharp so there is error which we saw 0.94 wala
# Out:
#        hba1c_start   hba1c_end  hba1c_change
# count   280.000000  280.000000    171.000000
# mean      7.985929    7.589286      0.546023
# std       0.568638    0.569672      0.279555
# min       7.500000    7.010000      0.200000
# 25%       7.660000    7.270000      0.340000
# 50%       7.800000    7.420000      0.380000
# 75%       7.970000    7.570000      0.920000
# max       9.950000    9.580000      0.990000

# %%
patients.sample(5)
# Out:
#      patient_id assigned_sex given_name   surname                     address  \
# 219         220         male         Mỹ     Quynh                         NaN
# 102         103       female      Najla     Touma    2146 Willow Greene Drive
# 188         189         male      Søren  Sørensen            2397 Bell Street
# 165         166         male     Zlatko  Rukavina               592 Rafe Lane
# 62           63       female    Firenze     Fodor  1786 Gerald L. Bates Drive
#
#            city state  zip_code        country  \
# 219         NaN   NaN       NaN            NaN
# 102  Montgomery    AL   36104.0  United States
# 188    New York    NY   10011.0  United States
# 165  Yazoo City    MS   39194.0  United States
# 62      Belmont    MA    2178.0  United States
#
#                                         contact   birthdate  weight  height  \
# 219                                         NaN    4/9/1978   237.8      69
# ...

# %%
patients[patients['address'].duplicated()]
# here jhon doe patient is repeating
# Out:
#      patient_id assigned_sex given_name     surname             address  \
# 29           30         male       Jake    Jakobsen   648 Old Dear Lane
# 219         220         male         Mỹ       Quynh                 NaN
# 229         230         male       John         Doe     123 Main Street
# 230         231       female  Elisabeth     Knudsen                 NaN
# 234         235       female    Martina   Tománková                 NaN
# 237         238         male       John         Doe     123 Main Street
# 242         243         male       John     O'Brian                 NaN
# 244         245         male       John         Doe     123 Main Street
# 249         250         male   Benjamin      Mehler                 NaN
# 251         252         male       John         Doe     123 Main Street
# 257         258         male        Jin        Kung                 NaN
# 264         265       female   Wafiyyah      Asfour                 NaN
# ...

# %% [markdown]
# Tidiness issues
#
# 1. patients
#   - phone and email together in one contact column
#
# 2. Treatment
#   - 3 variables stored in orilin and novodra column
#
#
# 3. Adverse reaction
#   - no pooint using this table

# %% [markdown]
# Data Quality Dimensions
#  1. completeness issues
#  2. validity issues
#  3. accuracy issues
#  4. consistency issues
